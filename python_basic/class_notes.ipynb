# %%
print("hello zehan")
# Out:
# hello zehan

# %%
"""
hi
zehan
"""
# hi
# zehan
print("multi line comments")
# Out:
# multi line comments

# %%
print("hello, 'zehan'")
print('hello, "zehan"')
print("""hello, "zehan" """)
print("hello, \"zehan\" ")
# Out:
# hello, 'zehan'
# hello, "zehan"
# hello, "zehan"
# hello, "zehan"

# %%
# hidden value
__num = 10
__path = "url:path"
__API_KEY = "lkdjalkjsl"

# %%
# dummy variable
_ = 10

# %%
# Integer
a = 10
print(type(a))

# Float
pie = 3.14
print(type(pie))

# Complex number
c = 2 + 3j
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# Strong typing

# 33 + '33' // throw error

22 + 22 # valid
"33" + "33" # valid
22.44 + 1 # valid
# Out:
# 23.44

# %%
name = "zehan"

print(f"welcome {name} to python world")

print("welcome {} to python world".format(name))

print("weclome "+ name + " to python world")
# Out:
# welcome zehan to python world
# welcome zehan to python world
# weclome zehan to python world

# %%
# use reserve words
print = "hello"
print
# Out:
# 'hello'

# %%
print("hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-43d0290e3b7d> in <cell line: 1>()
# ----> 1 print("hello")
#
# TypeError: 'str' object is not callable

# %%
# how to restore reserve word
del print
print("hello")
# Out:
# hello

# %%
# del is a keyword and cannot be assigned
del = "hello"
del
# Out:
#   File "<ipython-input-6-334700dd02d6>", line 1
#     del = "hello"
#         ^
# SyntaxError: invalid syntax

# %%
# multi assign value
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c131d2a3480> in <cell line: 1>()
# ----> 1 type(yes)
#
# NameError: name 'yes' is not defined
